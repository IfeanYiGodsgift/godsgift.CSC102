# %%
import math

class GeometryCalculator:
    def area_of_trapezium(self, height, base1, base2):
        return height / 2 * (base1 + base2)

    def area_of_rhombus(self, diagonal1, diagonal2):
        return 0.5 * diagonal1 * diagonal2

    def area_of_parallelogram(self, base, altitude):
        return base * altitude
    
import math

class Shape:
    def __init__(self):
        pass

    def area(self):
        pass

    def volume(self):
        pass

class Trapezium(Shape):
    def __init__(self, height, base1, base2):
        self.height = height
        self.base1 = base1
        self.base2 = base2

    def area(self):
        return self.height/2*(self.base1+self.base2)

class Rhombus(Shape):
    def __init__(self, diagonal1, diagonal2):
        self.diagonal1 = diagonal1
        self.diagonal2 = diagonal2

    def area(self):
        return 0.5 * self.diagonal1 * self.diagonal2

class Parallelogram(Shape):
    def __init__(self, base, altitude):
        self.base = base
        self.altitude = altitude

    def area(self):
        return self.base * self.altitude

class Cube(Shape):
    def __init__(self, side_length):
        self.side_length = side_length

    def area(self):
        return 6 * (self.side_length ** 2)

class Cylinder(Shape
